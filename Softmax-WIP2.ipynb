# %%
# %matplotlib inline

import numpy as np
import cProfile
import random
from SNN_test import *
from NN import *
from WAVreader import *
from copy import deepcopy
from random import shuffle
from scipy.io import wavfile
from scipy.fftpack import fft, dct
from pylab import *
from numpy import dot, outer
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix

# %%
filelist = ['Audio/1-1.wav',
            'Audio/2-1.wav'
            ]
info = WAVreader(filelist, [], 0.05)
data = info.dataset
# Out:
# 14.4615
# Scaled 1005 windows down to 751
# Finished file Audio/1-1.wav
# 14.6035
# Scaled 883 windows down to 756
# Finished file Audio/2-1.wav
#
# Final data set consists of 1499 windows over 2 classes

# %%
trainset = []
testset = []
for i in xrange(len(data)):
    if i%10 < 3: testset.append(data[i])
    else: trainset.append(data[i])
print (len(data), len(testset))
# Out:
# (3043, 915)

# %%
SNN = SoftmaxNeuralNetwork(input_dim=79, output_dim=info.numClasses)
# print data[0][1]
# SNN.forward_propagation(data[0][0])
# print SNN.predictions
# SNN.backward_propagation(data[0][1])
SNN.train(trainset, maxiter=251, display_progress=True, anneal=lambda x: .01/(100+5*x*info.numClasses))
# Out:
# completed iteration 0; error is 1086.0; size is 0.176761201158
# completed iteration 10; error is 559.0; size is 0.185632209909
# completed iteration 20; error is 470.0; size is 0.189328102512
# completed iteration 30; error is 422.0; size is 0.190463155541
# completed iteration 40; error is 384.0; size is 0.191132326161
# completed iteration 50; error is 359.0; size is 0.191292090582
# completed iteration 60; error is 339.0; size is 0.19135584518
# completed iteration 70; error is 311.0; size is 0.191399937706
# completed iteration 80; error is 310.0; size is 0.191347410411
# completed iteration 90; error is 290.0; size is 0.191281461289
# completed iteration 100; error is 302.0; size is 0.191182771238
# completed iteration 110; error is 293.0; size is 0.191063783586
# completed iteration 120; error is 275.0; size is 0.190944236257
# completed iteration 130; error is 258.0; size is 0.190825059479
# completed iteration 140; error is 289.0; size is 0.190699450886
# completed iteration 150; error is 274.0; size is 0.190573077338
# completed iteration 160; error is 284.0; size is 0.190409328173
# completed iteration 170; error is 275.0; size is 0.190298239837
# completed iteration 180; error is 247.0; size is 0.190161331555
# completed iteration 190; error is 269.0; size is 0.190048458082
# completed iteration 200; error is 257.0; size is 0.189931906206
# completed iteration 210; error is 267.0; size is 0.189823945253
# completed iteration 220; error is 249.0; size is 0.189688910292
# completed iteration 230; error is 259.0; size is 0.189587206229
# completed iteration 240; error is 238.0; size is 0.189502206273
# completed iteration 250; error is 264.0; size is 0.18940632857

# %%
# 2-class, alpha=.001, lmbda=.0001, t=101
print SNN.accuracy(trainset), SNN.accuracy(testset)
# Out:
# 0.866541353383 0.863387978142

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

ytrue = []
ypred = []
for clip in testset:
    SNN.forward_propagation(clip[0])
    ypred.append(np.argmax(SNN.predictions))
    ytrue.append(np.argmax(clip[1]))
confusion=confusion_matrix(ytrue, ypred)
cm_normalized = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
print('Confusion matrix')
print(confusion)
plt.figure()
plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')
# Out:
# Confusion matrix
# [[423  30]
#  [ 95 367]]

# %%
precisions = np.array([(confusion[i][i]+0.0)/np.sum(confusion, axis=0)[i] for i in range(info.numClasses)])
meanp = np.mean(precisions)
recalls = np.array([(confusion[i][i]+0.0)/sum(confusion[i]) for i in range(info.numClasses)])
meanr = np.mean(recalls)
F1 = 2*meanr*meanp/(meanr+meanp)
print meanp
print meanr
print F1
# Out:
# 0.870517782986
# 0.864073564405
# 0.867283703166

# %%
def pcaplot(pull):
    colors = ['red','blue','green','purple','orange','yellow','brown','black']

    X = [dat[0] for dat in pull]
    labels = [(dat[1]+0.0)/info.length*2 for dat in pull]
    pca = PCA(n_components=2)
    pca.fit(X)
    newX = pca.transform(X)
    figure()
    for label in range(info.numClasses,-1,-1):
        series = [newX[i] for i in range(len(newX)) if pull[i][1]==label and i%3==0]
        scatter([x[0] for x in series], [x[1] for x in series],c=colors[label],alpha=0.5,s=10)
    plt.title("PCA representation of concatenated supervectors (2-class)")
    show()

pcaplot(info.svmset)

# %%
#SIMPLE TIMER
cProfile.run("rate, x = wavfile.read('5-1.wav');")
print rate, len(x)

# %%
#MORE COMPLEX TIMER - BUT POSSIBLY CAN EXTRACT INFO INTO VARIABLES
import cProfile, pstats, StringIO
pr = cProfile.Profile()
pr.enable()
pr.run("rate, x = wavfile.read('5-1.wav');")
pr.disable()
s = StringIO.StringIO()
ps = pstats.Stats(pr, stream=s).strip_dirs()
ps.print_stats()
print s.getvalue()
# Out:
#          34665 function calls (34281 primitive calls) in 0.040 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 transforms.py:999(_get_minposy)
#        10    0.000    0.000    0.000    0.000 cbook.py:363(__init__)
#         1    0.000    0.000    0.000    0.000 figure.py:99(bubble)
#       197    0.000    0.000    0.000    0.000 {method 'itervalues' of 'dict' objects}
#        20    0.000    0.000    0.000    0.000 artist.py:261(get_transform)
#        16    0.000    0.000    0.000    0.000 ticker.py:390(__init__)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:53(take)
#     81/78    0.000    0.000    0.000    0.000 {hash}
#        10    0.000    0.000    0.000    0.000 cbook.py:495(connect)
#        95    0.000    0.000    0.000    0.000 text.py:1020(set_text)
#         2    0.000    0.000    0.000    0.000 lines.py:542(set_axes)
#       3/2    0.000    0.000    0.000    0.000 transforms.py:1609(__eq__)
#         1    0.000    0.000    0.000    0.000 pyplot.py:467(get_fignums)
#       229    0.000    0.000    0.002    0.000 transforms.py:161(set_children)
#       210    0.001    0.000    0.001    0.000 artist.py:79(__init__)
#        10    0.000    0.000    0.000    0.000 weakref.py:261(__setitem__)
#         6    0.000    0.000    0.000    0.000 transforms.py:2657(nonsingular)
#         1    0.000    0.000    0.000    0.000 figure.py:775(_make_key)
#         4    0.000    0.000    0.000    0.000 transforms.py:372(_get_intervaly)
#        11    0.000    0.000    0.000    0.000 patches.py:260(set_edgecolor)
#       129    0.000    0.000    0.000    0.000 lines.py:1048(set_ydata)
#         4    0.000    0.000    0.015    0.004 spines.py:159(cla)
#         1    0.000    0.000    0.000    0.000 path.py:221(codes)
#         1    0.000    0.000    0.000    0.000 artist.py:629(get_clip_on)
#       425    0.001    0.000    0.006    0.000 path.py:103(__init__)
#         4    0.000    0.000    0.000    0.000 path.py:207(vertices)
#         1    0.000    0.000    0.000    0.000 widgets.py:36(__init__)
#         2    0.000    0.000    0.000    0.000 font_manager.py:929(copy)
#        16    0.000    0.000    0.004    0.000 axis.py:420(_get_gridline)
#        16    0.000    0.000    0.000    0.000 axis.py:1506(set_major_locator)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2142(amin)
#       149    0.000    0.000    0.000    0.000 weakref.py:48(remove)
#        12    0.000    0.000    0.000    0.000 figure.py:227(_update_this)
#        44    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       260    0.000    0.000    0.000    0.000 markers.py:267(_set_nothing)
#         6    0.000    0.000    0.000    0.000 patches.py:386(set_joinstyle)
#         1    0.000    0.000    0.000    0.000 path.py:259(should_simplify)
#         1    0.000    0.000    0.000    0.000 _base.py:260(_plot_args)
#       108    0.000    0.000    0.002    0.000 transforms.py:1132(__add__)
#        71    0.000    0.000    0.000    0.000 text.py:258(set_rotation_mode)
#        97    0.000    0.000    0.000    0.000 lines.py:1031(set_markersize)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2550(__init__)
#         2    0.000    0.000    0.000    0.000 _base.py:296(_grab_next_args)
#        10    0.000    0.000    0.000    0.000 patches.py:370(set_capstyle)
#         1    0.000    0.000    0.000    0.000 _base.py:197(_xy_from_xy)
#         1    0.000    0.000    0.001    0.001 _axes.py:1242(plot)
#         1    0.000    0.000    0.000    0.000 gridspec.py:66(set_width_ratios)
#        24    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 spines.py:437(linear_spine)
#         4    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 figure.py:390(_get_axes)
#         1    0.000    0.000    0.000    0.000 transforms.py:978(_set_intervaly)
#         2    0.000    0.000    0.000    0.000 figure.py:188(update)
#        65    0.000    0.000    0.001    0.000 transforms.py:2564(__init__)
#        64    0.000    0.000    0.000    0.000 ticker.py:186(set_axis)
#         1    0.000    0.000    0.000    0.000 __init__.py:70(process_projection_requirements)
#         1    0.000    0.000    0.000    0.000 _base.py:2167(grid)
#         1    0.000    0.000    0.014    0.014 _base.py:480(_init_axis)
#         2    0.000    0.000    0.000    0.000 cbook.py:1335(push)
#         3    0.000    0.000    0.000    0.000 gridspec.py:476(__hash__)
#         8    0.000    0.000    0.002    0.000 axis.py:175(set_clip_path)
#       730    0.000    0.000    0.001    0.000 numeric.py:394(asarray)
#        97    0.000    0.000    0.000    0.000 lines.py:1277(set_dash_capstyle)
#        69    0.000    0.000    0.000    0.000 font_manager.py:905(set_file)
#        20    0.000    0.000    0.000    0.000 colors.py:353(<genexpr>)
#         4    0.000    0.000    0.000    0.000 scale.py:494(scale_factory)
#         1    0.000    0.000    0.000    0.000 _base.py:1917(autoscale_view)
#       108    0.000    0.000    0.001    0.000 transforms.py:2215(__init__)
#         1    0.000    0.000    0.001    0.001 wavfile.py:51(_read_data_chunk)
#       149    0.000    0.000    0.001    0.000 numeric.py:2125(identity)
#       160    0.000    0.000    0.000    0.000 axis.py:272(_set_artist_props)
#         1    0.000    0.000    0.000    0.000 transforms.py:1185(contains_branch)
#         1    0.000    0.000    0.000    0.000 _base.py:797(_gen_axes_spines)
#         8    0.000    0.000    0.007    0.001 spines.py:349(set_position)
#         1    0.000    0.000    0.000    0.000 transforms.py:813(null)
#        97    0.000    0.000    0.000    0.000 lines.py:645(set_transform)
#         2    0.000    0.000    0.000    0.000 {math.ceil}
#         1    0.000    0.000    0.000    0.000 axis.py:1664(_get_label)
#         1    0.000    0.000    0.000    0.000 {numpy.core.multiarray.fromstring}
#         2    0.000    0.000    0.000    0.000 ticker.py:1326(bin_boundaries)
#       367    0.000    0.000    0.000    0.000 weakref.py:223(__new__)
#       197    0.000    0.000    0.000    0.000 six.py:572(itervalues)
#         1    0.000    0.000    0.001    0.001 pyplot.py:327(figure)
#        16    0.000    0.000    0.000    0.000 axis.py:1496(set_minor_formatter)
#        16    0.000    0.000    0.001    0.000 axis.py:478(_get_text2_transform)
#        16    0.000    0.000    0.001    0.000 axis.py:333(_get_text1_transform)
#         1    0.000    0.000    0.000    0.000 _subplots.py:110(update_params)
#       843    0.000    0.000    0.001    0.000 UserDict.py:4(__init__)
#        97    0.000    0.000    0.000    0.000 lines.py:1243(set_dash_joinstyle)
#       180    0.000    0.000    0.001    0.000 artist.py:745(update)
#         2    0.000    0.000    0.000    0.000 figure.py:134(current_key_axes)
#         2    0.000    0.000    0.000    0.000 artist.py:770(set_label)
#        69    0.000    0.000    0.000    0.000 _weakrefset.py:68(__contains__)
#        16    0.000    0.000    0.001    0.000 _base.py:599(get_xaxis_text2_transform)
#     16/14    0.000    0.000    0.006    0.000 axis.py:389(_get_tick1line)
#        72    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       148    0.000    0.000    0.002    0.000 transforms.py:1739(__init__)
#         1    0.000    0.000    0.000    0.000 figure.py:1227(_set_artist_props)
#         1    0.000    0.000    0.000    0.000 hooks.py:192(pre_run_code_hook)
#         1    0.000    0.000    0.037    0.037 _base.py:329(__init__)
#         1    0.000    0.000    0.000    0.000 copy.py:123(_copy_inst)
#         2    0.000    0.000    0.000    0.000 transforms.py:1158(_iter_break_from_left_to_right)
#        16    0.000    0.000    0.001    0.000 _base.py:676(get_yaxis_text2_transform)
#        32    0.000    0.000    0.001    0.000 markers.py:685(_set_tickright)
#         1    0.000    0.000    0.040    0.040 <ipython-input-28-f8e84d8fe309>:4(<module>)
#         1    0.000    0.000    0.000    0.000 axis.py:1901(get_minpos)
#       129    0.000    0.000    0.002    0.000 transforms.py:1900(scale)
#         2    0.000    0.000    0.000    0.000 transforms.py:280(__array__)
#         1    0.000    0.000    0.037    0.037 _subplots.py:23(__init__)
#         1    0.000    0.000    0.000    0.000 transforms.py:1205(contains_branch_seperately)
#         1    0.000    0.000    0.000    0.000 backend_agg.py:431(new_figure_manager_given_figure)
#         3    0.000    0.000    0.000    0.000 artist.py:551(set_clip_box)
#         1    0.000    0.000    0.000    0.000 axis.py:1438(have_units)
#         1    0.000    0.000    0.000    0.000 {compile}
#       431    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 axis.py:1966(_get_label)
#         4    0.000    0.000    0.000    0.000 {any}
#        16    0.000    0.000    0.003    0.000 axis.py:559(_get_gridline)
#         1    0.000    0.000    0.000    0.000 _base.py:2583(get_xscale)
#        16    0.000    0.000    0.001    0.000 axis.py:475(_get_text1_transform)
#        97    0.000    0.000    0.000    0.000 lines.py:1020(set_markerfacecoloralt)
#       843    0.001    0.000    0.002    0.000 weakref.py:47(__init__)
#        17    0.000    0.000    0.000    0.000 patches.py:275(set_facecolor)
#         2    0.000    0.000    0.000    0.000 {math.log10}
#         2    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.002    0.000 axis.py:513(_get_text2)
#        69    0.000    0.000    0.000    0.000 font_manager.py:854(set_weight)
#        73    0.000    0.000    0.000    0.000 artist.py:155(convert_xunits)
#       367    0.000    0.000    0.000    0.000 {id}
#        12    0.000    0.000    0.000    0.000 {setattr}
#       186    0.000    0.000    0.000    0.000 {numpy.core._dotblas.dot}
#    144/96    0.000    0.000    0.008    0.000 spines.py:142(_ensure_position_is_set)
#         7    0.000    0.000    0.000    0.000 {range}
#        32    0.000    0.000    0.000    0.000 cbook.py:1393(popall)
#        12    0.000    0.000    0.032    0.003 axis.py:725(cla)
#         8    0.000    0.000    0.000    0.000 transforms.py:2191(blended_transform_factory)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1852(all)
#        55    0.000    0.000    0.000    0.000 axis.py:694(get_scale)
#        97    0.000    0.000    0.000    0.000 lines.py:1254(set_solid_joinstyle)
#       819    0.000    0.000    0.001    0.000 six.py:575(iteritems)
#        71    0.000    0.000    0.001    0.000 text.py:160(__init__)
#         2    0.000    0.000    0.000    0.000 transforms.py:2018(__init__)
#        69    0.000    0.000    0.000    0.000 abc.py:128(__instancecheck__)
#    148/60    0.000    0.000    0.004    0.000 _base.py:548(get_xaxis_transform)
#         8    0.000    0.000    0.000    0.000 spines.py:275(_calc_offset_transform)
#         1    0.000    0.000    0.000    0.000 _base.py:3027(set_navigate)
#         2    0.000    0.000    0.005    0.002 axis.py:625(__init__)
#         3    0.000    0.000    0.000    0.000 text.py:526(_update_clip_properties)
#        69    0.000    0.000    0.000    0.000 font_manager.py:832(set_style)
#        19    0.000    0.000    0.000    0.000 transforms.py:1838(rotate)
#        16    0.000    0.000    0.000    0.000 text.py:979(set_x)
#         9    0.000    0.000    0.000    0.000 {max}
#         2    0.000    0.000    0.003    0.001 axis.py:858(set_clip_path)
#         2    0.000    0.000    0.000    0.000 {min}
#        11    0.000    0.000    0.000    0.000 patches.py:324(set_linewidth)
#         1    0.000    0.000    0.000    0.000 gridspec.py:37(__init__)
#     16/14    0.000    0.000    0.005    0.000 axis.py:404(_get_tick2line)
#        97    0.000    0.000    0.000    0.000 lines.py:914(set_linewidth)
#      2802    0.001    0.000    0.001    0.000 __init__.py:871(__getitem__)
#        19    0.000    0.000    0.002    0.000 patches.py:185(get_transform)
#         1    0.000    0.000    0.000    0.000 lines.py:655(_is_sorted)
#       848    0.000    0.000    0.001    0.000 core.py:5776(isMaskedArray)
#         6    0.000    0.000    0.000    0.000 transforms.py:2131(__init__)
#         2    0.000    0.000    0.000    0.000 _base.py:152(set_color_cycle)
#        16    0.000    0.000    0.000    0.000 axis.py:1486(set_major_formatter)
#        97    0.000    0.000    0.000    0.000 lines.py:885(set_antialiased)
#         4    0.000    0.000    0.000    0.000 _base.py:773(_set_artist_props)
#        20    0.000    0.000    0.000    0.000 transforms.py:821(from_bounds)
#         2    0.000    0.000    0.000    0.000 _base.py:702(_update_transScale)
#         1    0.000    0.000    0.000    0.000 gridspec.py:387(__init__)
#       194    0.001    0.000    0.008    0.000 markers.py:229(set_marker)
#         2    0.000    0.000    0.000    0.000 axis.py:1278(get_major_locator)
#        97    0.000    0.000    0.000    0.000 {callable}
#        69    0.000    0.000    0.000    0.000 font_manager.py:872(set_stretch)
#         4    0.000    0.000    0.000    0.000 spines.py:43(__init__)
#         4    0.000    0.000    0.009    0.002 spines.py:148(register_axis)
#       149    0.000    0.000    0.001    0.000 twodim_base.py:190(eye)
#       182    0.000    0.000    0.000    0.000 artist.py:250(set_transform)
#         4    0.000    0.000    0.000    0.000 axis.py:691(get_transform)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:116(get_active)
#         3    0.000    0.000    0.000    0.000 cbook.py:1355(clear)
#         1    0.000    0.000    0.000    0.000 figure.py:69(__init__)
#         2    0.000    0.000    0.000    0.000 ticker.py:1225(scale_range)
#         4    0.000    0.000    0.000    0.000 scale.py:66(__init__)
#        16    0.000    0.000    0.002    0.000 axis.py:372(_get_text2)
#        18    0.000    0.000    0.000    0.000 cbook.py:475(__init__)
#         4    0.000    0.000    0.000    0.000 transforms.py:365(_get_intervalx)
#       108    0.000    0.000    0.000    0.000 {hasattr}
#       4/2    0.000    0.000    0.000    0.000 transforms.py:2271(depth)
#        97    0.000    0.000    0.000    0.000 lines.py:552(set_data)
#        19    0.000    0.000    0.002    0.000 patches.py:609(_update_patch_transform)
#       843    0.001    0.000    0.003    0.000 transforms.py:85(__init__)
#         1    0.000    0.000    0.000    0.000 _base.py:2738(set_ylim)
#         2    0.000    0.000    0.000    0.000 artist.py:621(get_visible)
#        33    0.000    0.000    0.001    0.000 lines.py:868(get_path)
#         2    0.000    0.000    0.000    0.000 _base.py:139(__init__)
#         4    0.000    0.000    0.000    0.000 cbook.py:1733(get_siblings)
#        97    0.000    0.000    0.000    0.000 lines.py:1290(set_solid_capstyle)
#        97    0.000    0.000    0.000    0.000 lines.py:999(set_markeredgewidth)
#         2    0.000    0.000    0.000    0.000 patches.py:580(__init__)
#         1    0.000    0.000    0.000    0.000 _base.py:1493(add_line)
#         1    0.000    0.000    0.000    0.000 wavfile.py:94(_read_riff_chunk)
#         1    0.000    0.000    0.000    0.000 gridspec.py:416(get_position)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:38(get_fig_manager)
#         1    0.000    0.000    0.000    0.000 figure.py:1276(sca)
#         1    0.000    0.000    0.000    0.000 artist.py:764(get_label)
#    148/60    0.000    0.000    0.004    0.000 _base.py:625(get_yaxis_transform)
#         1    0.000    0.000    0.000    0.000 __init__.py:303(report)
#        68    0.000    0.000    0.000    0.000 artist.py:788(set_zorder)
#         3    0.000    0.000    0.000    0.000 {repr}
#         1    0.000    0.000    0.000    0.000 _methods.py:28(_amin)
#       233    0.000    0.000    0.000    0.000 artist.py:541(set_figure)
#        12    0.000    0.000    0.000    0.000 axis.py:1451(set_units)
#         6    0.000    0.000    0.000    0.000 patches.py:67(__init__)
#         1    0.000    0.000    0.000    0.000 artist.py:637(get_clip_path)
#       129    0.000    0.000    0.000    0.000 lines.py:1039(set_xdata)
#         1    0.000    0.000    0.000    0.000 {method 'close' of 'file' objects}
#         1    0.000    0.000    0.000    0.000 wavfile.py:33(_read_fmt_chunk)
#      2212    0.001    0.000    0.001    0.000 {isinstance}
#         1    0.000    0.000    0.000    0.000 __init__.py:54(get_projection_class)
#        12    0.000    0.000    0.000    0.000 axis.py:1404(_update_axisinfo)
#         3    0.000    0.000    0.000    0.000 six.py:569(iterkeys)
#         1    0.000    0.000    0.000    0.000 gridspec.py:72(set_height_ratios)
#         7    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 figure.py:537(set_canvas)
#        97    0.000    0.000    0.000    0.000 lines.py:461(set_markevery)
#     32/24    0.001    0.000    0.031    0.001 axis.py:67(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:147(__call__)
#         1    0.000    0.000    0.000    0.000 _subplots.py:102(get_subplotspec)
#         1    0.000    0.000    0.000    0.000 axis.py:1683(_get_offset_text)
#         1    0.000    0.000    0.001    0.001 wavfile.py:116(read)
#         1    0.000    0.000    0.000    0.000 gridspec.py:194(__init__)
#         1    0.000    0.000    0.000    0.000 gridspec.py:403(get_gridspec)
#      14/9    0.000    0.000    0.000    0.000 units.py:125(get_converter)
#         1    0.000    0.000    0.037    0.037 figure.py:886(add_subplot)
#     16/12    0.000    0.000    0.016    0.001 axis.py:1657(_get_tick)
#         8    0.001    0.000    0.001    0.000 {method 'read' of 'file' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:2705(set_ybound)
#       819    0.000    0.000    0.000    0.000 {method 'iteritems' of 'dict' objects}
#        32    0.000    0.000    0.000    0.000 ticker.py:1297(set_params)
#        29    0.000    0.000    0.000    0.000 colors.py:334(to_rgba)
#         1    0.000    0.000    0.000    0.000 path.py:240(simplify_threshold)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:125(set_active)
#        88    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 transforms.py:1539(_set)
#        16    0.000    0.000    0.000    0.000 ticker.py:413(set_useOffset)
#        22    0.000    0.000    0.000    0.000 transforms.py:1051(__init__)
#      36/3    0.000    0.000    0.000    0.000 transforms.py:2244(_invalidate_internal)
#         1    0.000    0.000    0.040    0.040 cProfile.py:132(run)
#         2    0.000    0.000    0.000    0.000 transforms.py:717(union)
#       367    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x000000001E29D0F0}
#         1    0.000    0.000    0.000    0.000 transforms.py:2530(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:25(get_projection_class)
#        69    0.000    0.000    0.000    0.000 font_manager.py:844(set_variant)
#      1422    0.000    0.000    0.000    0.000 {iter}
#         1    0.000    0.000    0.000    0.000 gridspec.py:135(__getitem__)
#         1    0.000    0.000    0.000    0.000 _base.py:1686(_process_unit_info)
#         1    0.000    0.000    0.000    0.000 patches.py:256(set_aa)
#         1    0.000    0.000    0.000    0.000 ipstruct.py:125(__getattr__)
#        32    0.000    0.000    0.000    0.000 artist.py:706(set_alpha)
#       425    0.002    0.000    0.004    0.000 path.py:199(_update_values)
#        32    0.000    0.000    0.001    0.000 markers.py:699(_set_tickdown)
#         1    0.000    0.000    0.000    0.000 transforms.py:2158(__eq__)
#         1    0.000    0.000    0.000    0.000 figure.py:398(_set_dpi)
#        10    0.000    0.000    0.000    0.000 weakref.py:293(__contains__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1335(get_backend)
#         1    0.000    0.000    0.000    0.000 cbook.py:1360(bubble)
#         7    0.000    0.000    0.000    0.000 patches.py:246(set_antialiased)
#        20    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:2491(set_xlim)
#     16/12    0.000    0.000    0.031    0.003 axis.py:760(reset_ticks)
#        73    0.000    0.000    0.000    0.000 artist.py:165(convert_yunits)
#        97    0.000    0.000    0.000    0.000 cbook.py:735(is_numlike)
#         1    0.000    0.000    0.000    0.000 __init__.py:335(ge)
#        16    0.000    0.000    0.000    0.000 text.py:987(set_y)
#        38    0.000    0.000    0.000    0.000 transforms.py:1885(translate)
#        16    0.000    0.000    0.002    0.000 axis.py:354(_get_text1)
#         1    0.000    0.000    0.000    0.000 _base.py:2694(get_ybound)
#         2    0.000    0.000    0.000    0.000 scale.py:48(limit_range_for_scale)
#         1    0.000    0.000    0.040    0.040 cProfile.py:137(runctx)
#         1    0.000    0.000    0.000    0.000 figure.py:794(fixlist)
#      1007    0.001    0.000    0.001    0.000 {numpy.core.multiarray.array}
#         1    0.000    0.000    0.000    0.000 transforms.py:883(update_from_path)
#         1    0.000    0.000    0.037    0.037 pyplot.py:935(subplots)
#         1    0.000    0.000    0.000    0.000 figure.py:410(set_tight_layout)
#        97    0.000    0.000    0.000    0.000 lines.py:1009(set_markerfacecolor)
#         4    0.000    0.000    0.000    0.000 axis.py:704(_set_scale)
#        69    0.000    0.000    0.000    0.000 font_manager.py:890(set_size)
#       388    0.001    0.000    0.013    0.000 markers.py:182(_recache)
#        97    0.000    0.000    0.005    0.000 lines.py:972(set_marker)
#         4    0.000    0.000    0.000    0.000 backend_bases.py:2271(mpl_connect)
#       636    0.000    0.000    0.001    0.000 artist.py:235(pchanged)
#        16    0.000    0.000    0.000    0.000 ticker.py:1697(__init__)
#         1    0.000    0.000    0.000    0.000 _base.py:2445(get_xbound)
#        43    0.000    0.000    0.000    0.000 transforms.py:774(__init__)
#         1    0.000    0.000    0.000    0.000 codeop.py:132(__call__)
#        16    0.000    0.000    0.000    0.000 axis.py:436(update_position)
#         2    0.000    0.000    0.000    0.000 transforms.py:1504(__init__)
#        19    0.000    0.000    0.000    0.000 transforms.py:1855(rotate_deg)
#         1    0.000    0.000    0.000    0.000 _base.py:1511(_update_line_limits)
#         3    0.000    0.000    0.000    0.000 shape_base.py:8(atleast_1d)
#       108    0.000    0.000    0.002    0.000 transforms.py:2390(composite_transform_factory)
#         1    0.000    0.000    0.040    0.040 interactiveshell.py:3005(run_code)
#       485    0.000    0.000    0.000    0.000 {method 'startswith' of 'unicode' objects}
#         1    0.000    0.000    0.022    0.022 _base.py:817(cla)
#         4    0.000    0.000    0.000    0.000 gridspec.py:50(get_geometry)
#         1    0.000    0.000    0.000    0.000 cbook.py:779(_string_to_bool)
#       556    0.000    0.000    0.000    0.000 {getattr}
#         1    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 axis.py:1382(update_units)
#       311    0.001    0.000    0.001    0.000 cbook.py:681(is_string_like)
#         1    0.000    0.000    0.000    0.000 _base.py:179(set_lineprops)
#       390    0.000    0.000    0.000    0.000 {numpy.core.multiarray.empty}
#     16/14    0.000    0.000    0.005    0.000 axis.py:528(_get_tick1line)
#         1    0.000    0.000    0.000    0.000 _base.py:490(set_figure)
#      1728    0.000    0.000    0.000    0.000 {len}
#        33    0.000    0.000    0.001    0.000 lines.py:569(recache)
#     16/12    0.000    0.000    0.015    0.001 axis.py:1959(_get_tick)
#       194    0.000    0.000    0.006    0.000 markers.py:206(set_fillstyle)
#         1    0.000    0.000    0.000    0.000 {zip}
#         6    0.000    0.000    0.000    0.000 numeric.py:464(asanyarray)
#         6    0.000    0.000    0.000    0.000 cbook.py:1665(clean)
#         1    0.000    0.000    0.000    0.000 _subplots.py:161(subplot_class_factory)
#         2    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 scale.py:69(set_default_locators_and_formatters)
#        12    0.000    0.000    0.000    0.000 axis.py:1474(set_label_text)
#         1    0.000    0.000    0.000    0.000 scale.py:488(get_scale_names)
#         1    0.000    0.000    0.000    0.000 {method 'enable' of '_lsprof.Profiler' objects}
#         3    0.000    0.000    0.000    0.000 transforms.py:2275(_get_is_affine)
#         1    0.000    0.000    0.000    0.000 axis.py:2206(get_minpos)
#       403    0.000    0.000    0.001    0.000 cbook.py:672(iterable)
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 figure.py:81(get)
#         1    0.000    0.000    0.000    0.000 figure.py:260(__init__)
#        21    0.000    0.000    0.000    0.000 transforms.py:831(from_extents)
#        16    0.000    0.000    0.001    0.000 _base.py:573(get_xaxis_text1_transform)
#         4    0.000    0.000    0.000    0.000 artist.py:243(is_transform_set)
#        16    0.000    0.000    0.001    0.000 _base.py:650(get_yaxis_text1_transform)
#         2    0.000    0.000    0.000    0.000 axis.py:1341(grid)
#         6    0.000    0.000    0.000    0.000 patches.py:338(set_linestyle)
#         1    0.000    0.000    0.000    0.000 {open}
#         3    0.000    0.000    0.000    0.000 text.py:536(set_clip_box)
#         1    0.000    0.000    0.000    0.000 _base.py:2458(set_xbound)
#       367    0.000    0.000    0.000    0.000 weakref.py:228(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'accumulate' of 'numpy.ufunc' objects}
#        32    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       467    0.000    0.000    0.000    0.000 {method 'lower' of 'unicode' objects}
#       192    0.000    0.000    0.001    0.000 transforms.py:126(invalidate)
#        33    0.000    0.000    0.000    0.000 {numpy.core.multiarray.concatenate}
#        69    0.000    0.000    0.001    0.000 font_manager.py:815(set_family)
#         1    0.000    0.000    0.000    0.000 hooks.py:127(__call__)
#         1    0.000    0.000    0.000    0.000 _base.py:3166(set_cursor_props)
#         1    0.000    0.000    0.000    0.000 transforms.py:973(_set_intervalx)
#         1    0.000    0.000    0.000    0.000 transforms.py:1830(clear)
#        98    0.000    0.000    0.000    0.000 lines.py:893(set_color)
#         1    0.000    0.000    0.000    0.000 figure.py:106(add)
#         2    0.000    0.000    0.000    0.000 axis.py:713(limit_range_for_scale)
#        16    0.000    0.000    0.000    0.000 axis.py:1516(set_minor_locator)
#         3    0.000    0.000    0.000    0.000 {method 'tell' of 'file' objects}
#        32    0.000    0.000    0.001    0.000 markers.py:693(_set_tickup)
#        97    0.000    0.000    0.004    0.000 lines.py:452(set_fillstyle)
#       660    0.001    0.000    0.003    0.000 transforms.py:1593(__init__)
#        16    0.000    0.000    0.000    0.000 axis.py:575(update_position)
#         1    0.000    0.000    0.000    0.000 _base.py:781(_gen_axes_patch)
#        71    0.001    0.000    0.003    0.000 font_manager.py:655(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:73(as_list)
#       367    0.000    0.000    0.001    0.000 weakref.py:79(__setitem__)
#        14    0.000    0.000    0.000    0.000 transforms.py:1973(get_matrix)
#        19    0.000    0.000    0.002    0.000 patches.py:625(get_patch_transform)
#         1    0.000    0.000    0.000    0.000 gridspec.py:256(get_subplot_params)
#         6    0.000    0.000    0.000    0.000 axis.py:1441(convert_units)
#        21    0.000    0.000    0.000    0.000 transforms.py:2468(__init__)
#         1    0.000    0.000    0.000    0.000 _base.py:758(set_axes_locator)
#         1    0.000    0.000    0.000    0.000 {next}
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:1107(user_global_ns)
#   239/192    0.001    0.000    0.001    0.000 transforms.py:137(_invalidate_internal)
#         1    0.000    0.000    0.000    0.000 figure.py:778(fixitems)
#         1    0.000    0.000    0.000    0.000 transforms.py:2174(get_matrix)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1291(ravel)
#        28    0.000    0.000    0.000    0.000 axis.py:892(_set_artist_props)
#         3    0.000    0.000    0.000    0.000 {method 'iterkeys' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {divmod}
#       430    0.000    0.000    0.001    0.000 _methods.py:40(_all)
#         8    0.000    0.000    0.000    0.000 transforms.py:1670(_get_is_separable)
#       244    0.000    0.000    0.000    0.000 weakref.py:146(itervalues)
#        32    0.000    0.000    0.001    0.000 markers.py:679(_set_tickleft)
#         2    0.000    0.000    0.000    0.000 transforms.py:1557(set)
#        97    0.000    0.000    0.000    0.000 lines.py:901(set_drawstyle)
#         1    0.000    0.000    0.000    0.000 backend_inline.py:47(draw_if_interactive)
#         1    0.000    0.000    0.000    0.000 __init__.py:1347(is_interactive)
#        26    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:2689(yaxis_inverted)
#         1    0.000    0.000    0.000    0.000 index_tricks.py:151(__getitem__)
#       430    0.000    0.000    0.002    0.000 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 transforms.py:1573(_get_is_affine)
#       152    0.000    0.000    0.000    0.000 {numpy.core.multiarray.zeros}
#    136/96    0.000    0.000    0.008    0.000 spines.py:389(get_spine_transform)
#         1    0.000    0.000    0.000    0.000 _base.py:2440(xaxis_inverted)
#         1    0.000    0.000    0.000    0.000 figure.py:150(__contains__)
#         1    0.000    0.000    0.000    0.000 _base.py:1091(set_anchor)
#       3/2    0.000    0.000    0.000    0.000 transforms.py:2259(__eq__)
#         4    0.000    0.000    0.000    0.000 scale.py:79(get_transform)
#         1    0.000    0.000    0.000    0.000 gridspec.py:79(get_grid_positions)
#         1    0.000    0.000    0.000    0.000 _base.py:157(__call__)
#         6    0.000    0.000    0.000    0.000 artist.py:174(set_axes)
#        16    0.000    0.000    0.000    0.000 axis.py:339(apply_tickdir)
#        16    0.000    0.000    0.000    0.000 ticker.py:1257(__init__)
#         1    0.000    0.000    0.000    0.000 backend_agg.py:418(new_figure_manager)
#         1    0.000    0.000    0.000    0.000 numeric.py:1782(indices)
#         3    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {numpy.core.multiarray.arange}
#         3    0.000    0.000    0.000    0.000 _base.py:2732(get_ylim)
#     16/14    0.000    0.000    0.005    0.000 axis.py:544(_get_tick2line)
#         1    0.000    0.000    0.000    0.000 figure.py:91(_entry_from_axes)
#        97    0.000    0.000    0.000    0.000 lines.py:922(set_linestyle)
#         1    0.000    0.000    0.000    0.000 _base.py:3041(set_navigate_mode)
#        97    0.000    0.000    0.006    0.000 markers.py:148(__init__)
#        14    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        97    0.002    0.000    0.020    0.000 lines.py:249(__init__)
#        20    0.000    0.000    0.000    0.000 transforms.py:805(unit)
#         1    0.000    0.000    0.000    0.000 copy.py:66(copy)
#         2    0.000    0.000    0.000    0.000 transforms.py:2265(_iter_break_from_left_to_right)
#         1    0.000    0.000    0.000    0.000 transforms.py:1516(__eq__)
#         6    0.000    0.000    0.000    0.000 patches.py:402(set_hatch)
#         2    0.000    0.000    0.000    0.000 ticker.py:1368(view_limits)
#         1    0.000    0.000    0.000    0.000 figure.py:158(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method update_path_extents}
#        16    0.000    0.000    0.002    0.000 axis.py:497(_get_text1)
#         1    0.000    0.000    0.040    0.040 <string>:1(<module>)
#         9    0.000    0.000    0.000    0.000 weakref.py:245(remove)
#        97    0.000    0.000    0.000    0.000 lines.py:989(set_markeredgecolor)
#         3    0.000    0.000    0.000    0.000 _base.py:2485(get_xlim)
#         1    0.000    0.000    0.000    0.000 transforms.py:276(frozen)
#         1    0.000    0.000    0.000    0.000 _base.py:508(_set_lim_and_transforms)
#         1    0.000    0.000    0.000    0.000 figure.py:970(clf)
#        19    0.000    0.000    0.001    0.000 transforms.py:1875(rotate_deg_around)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1663(__init__)
#         1    0.000    0.000    0.000    0.000 transforms.py:995(_get_minposx)
#         1    0.000    0.000    0.000    0.000 _base.py:233(_makeline)
#        16    0.000    0.000    0.001    0.000 axis.py:336(_get_text2_transform)
#         6    0.000    0.000    0.000    0.000 patches.py:352(set_fill)
#        27    0.000    0.000    0.000    0.000 cbook.py:529(process)
#        16    0.000    0.000    0.000    0.000 {abs}
#         1    0.000    0.000    0.000    0.000 cbook.py:1305(__init__)
#         1    0.000    0.000    0.000    0.000 axis.py:1987(_get_offset_text)
#        11    0.000    0.000    0.000    0.000 transforms.py:1003(get_points)
#        19    0.000    0.000    0.003    0.000 artist.py:560(set_clip_path)
#         3    0.000    0.000    0.000    0.000 {_struct.unpack}
#        16    0.000    0.000    0.000    0.000 axis.py:481(apply_tickdir)
#        20    0.000    0.000    0.000    0.000 colors.py:265(to_rgb)
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'unicode' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:1013(set_aspect)
#         6    0.000    0.000    0.000    0.000 transforms.py:1171(depth)
#        71    0.000    0.000    0.000    0.000 text.py:824(set_color)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        10    0.000    0.000    0.000    0.000 weakref.py:243(__init__)
